# %%
import numpy as np 
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing DataSet

# %%
properties_fe = pd.read_csv("Property.csv")
properties_fe.head()
# Out:
#    property_id  location_id  \
# 0       347795            8
# 1       482892           48
# 2       555962           75
# 3       562843         3821
# 4       686990         3522
#
#                                             page_url property_type      price  \
# 0  https://www.zameen.com/Property/lahore_model_t...         House  220000000
# 1  https://www.zameen.com/Property/lahore_multan_...         House   40000000
# 2  https://www.zameen.com/Property/eden_eden_aven...         House    9500000
# 3  https://www.zameen.com/Property/gulberg_2_gulb...         House  125000000
# 4  https://www.zameen.com/Property/allama_iqbal_t...         House   21000000
#
#             location    city province_name   latitude  longitude  ...  \
# 0         Model Town  Lahore        Punjab  31.483869  74.325686  ...
# 1        Multan Road  Lahore        Punjab  31.431593  74.179980  ...
# 2               Eden  Lahore        Punjab  31.499348  74.416959  ...
# 3            Gulberg  Lahore        Punjab  31.522069  74.355512  ...
# 4  Allama Iqbal Town  Lahore        Punjab  31.506483  74.286017  ...
#
#    Unnamed: 21 Unnamed: 22 Unnamed: 23  Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0          NaN         NaN         NaN          NaN         NaN         NaN
# 1          NaN         NaN         NaN          NaN         NaN         NaN
# 2          NaN         NaN         NaN          NaN         NaN         NaN
# 3          NaN         NaN         NaN          NaN         NaN         NaN
# 4          NaN         NaN         NaN          NaN         NaN         NaN
#
#   Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 31 columns]

# %%
# Checking cities
print(properties_fe["city"].unique())
properties_fe.shape
# Out:
# ['Lahore' 'Karachi' 'Islamabad' 'Faisalabad' 'Rawalpindi' nan]
# (190904, 31)

# %%
# Subsetting the data with respect to Lahore
df = properties_fe[properties_fe["city"] == "Lahore"]

# %%
df = df.reset_index()
df = df.drop("index",axis=1)
df.head()
# Out:
#    property_id  location_id  \
# 0       347795            8
# 1       482892           48
# 2       555962           75
# 3       562843         3821
# 4       686990         3522
#
#                                             page_url property_type      price  \
# 0  https://www.zameen.com/Property/lahore_model_t...         House  220000000
# 1  https://www.zameen.com/Property/lahore_multan_...         House   40000000
# 2  https://www.zameen.com/Property/eden_eden_aven...         House    9500000
# 3  https://www.zameen.com/Property/gulberg_2_gulb...         House  125000000
# 4  https://www.zameen.com/Property/allama_iqbal_t...         House   21000000
#
#             location    city province_name   latitude  longitude  ...  \
# 0         Model Town  Lahore        Punjab  31.483869  74.325686  ...
# 1        Multan Road  Lahore        Punjab  31.431593  74.179980  ...
# 2               Eden  Lahore        Punjab  31.499348  74.416959  ...
# 3            Gulberg  Lahore        Punjab  31.522069  74.355512  ...
# 4  Allama Iqbal Town  Lahore        Punjab  31.506483  74.286017  ...
#
#    Unnamed: 21 Unnamed: 22 Unnamed: 23  Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0          NaN         NaN         NaN          NaN         NaN         NaN
# 1          NaN         NaN         NaN          NaN         NaN         NaN
# 2          NaN         NaN         NaN          NaN         NaN         NaN
# 3          NaN         NaN         NaN          NaN         NaN         NaN
# 4          NaN         NaN         NaN          NaN         NaN         NaN
#
#   Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 31 columns]

# %%
df = df.drop(df.columns[-14:], axis=1)
df.head()
# Out:
#    property_id  location_id  \
# 0       347795            8
# 1       482892           48
# 2       555962           75
# 3       562843         3821
# 4       686990         3522
#
#                                             page_url property_type      price  \
# 0  https://www.zameen.com/Property/lahore_model_t...         House  220000000
# 1  https://www.zameen.com/Property/lahore_multan_...         House   40000000
# 2  https://www.zameen.com/Property/eden_eden_aven...         House    9500000
# 3  https://www.zameen.com/Property/gulberg_2_gulb...         House  125000000
# 4  https://www.zameen.com/Property/allama_iqbal_t...         House   21000000
#
#             location    city province_name   latitude  longitude  baths  \
# 0         Model Town  Lahore        Punjab  31.483869  74.325686    0.0
# 1        Multan Road  Lahore        Punjab  31.431593  74.179980    5.0
# 2               Eden  Lahore        Punjab  31.499348  74.416959    0.0
# 3            Gulberg  Lahore        Punjab  31.522069  74.355512    7.0
# 4  Allama Iqbal Town  Lahore        Punjab  31.506483  74.286017    5.0
#
#        area   purpose  bedrooms  date_added                  agency  \
# 0   6 Kanal  For Sale       0.0  07-17-2019  Real Biz International
# 1   1 Kanal  For Sale       5.0  10/06/2018             Khan Estate
# 2   9 Marla  For Sale       3.0  07/03/2019         Shahum Estate 2
# 3   1 Kanal  For Sale       8.0  04/04/2019                     NaN
# 4  11 Marla  For Sale       6.0  04/04/2019                     NaN
#
#               agent
# 0        Usama Khan
# 1  mohsinkhan and B
# 2      Babar Hameed
# 3               NaN
# 4               NaN

# %%
print(df["property_type"].unique())
# Out:
# ['House' 'Flat' 'Lower Portion' 'Upper Portion' 'Room' 'Farm House'
#  'Penthouse']

# %%
# Romving all other types of properties
property_types_to_drop = ['Flat', 'Lower Portion', 'Penthouse', 'Upper Portion', 'Farm House', 'Room']
df.drop(df[df['property_type'].isin(property_types_to_drop)].index, inplace=True)

# %%
print(df["property_type"].unique())
# Out:
# ['House']

# %%
# dropping unnecessary columns
col_names = ["location_id","page_url","province_name","date_added","agency","agent","latitude","longitude","property_id","property_type","purpose","date_added","city"]
df = df.drop(col_names, axis=1)

# %%
df.head()
# Out:
#        price           location  baths      area  bedrooms
# 0  220000000         Model Town    0.0   6 Kanal       0.0
# 1   40000000        Multan Road    5.0   1 Kanal       5.0
# 2    9500000               Eden    0.0   9 Marla       3.0
# 3  125000000            Gulberg    7.0   1 Kanal       8.0
# 4   21000000  Allama Iqbal Town    5.0  11 Marla       6.0

# %%
# Checking if any null values in the df
df.isna().sum()
# Out:
# price       0
# location    0
# baths       0
# area        0
# bedrooms    2
# dtype: int64

# %%
# dropping the whole row
df = df.dropna()

# %%
# Checking if any null values in the df
df.isna().sum()
# Out:
# price       0
# location    0
# baths       0
# area        0
# bedrooms    0
# dtype: int64

# %%
# importing matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

df.shape
# Out:
# (49326, 5)

# %%
df['bedrooms'].unique()
# Out:
# array([ 0.,  5.,  3.,  8.,  6.,  4.,  2.,  7., 10., 11.,  9.,  1., 14.,
#        12., 13., 18., 15., 16., 25., 20.])

# %% [markdown]
# ## Data Cleaning

# %%
df[df['bedrooms']>13]
# Out:
#            price         location  baths       area  bedrooms
# 1099   100000000      Garden Town    0.0    2 Kanal      14.0
# 19678  650000000          Gulberg    0.0  4.6 Kanal      18.0
# 21785  175000000       Shah Jamal    0.0  4.8 Kanal      15.0
# 28412  350000000          Gulberg    0.0  3.2 Kanal      16.0
# 38495  175000000       Shah Jamal    0.0  4.8 Kanal      15.0
# 39910  960000000          Gulberg    0.0    8 Kanal      25.0
# 51905  960000000          Gulberg    0.0    8 Kanal      25.0
# 53239    1000000          Gulberg    0.0    4 Kanal      20.0
# 57475     300000  Habibullah Road    0.0  1.6 Kanal      20.0

# %%
df['baths'].unique()
# Out:
# array([ 0.,  5.,  7.,  6.,  4.,  3.,  2.,  8., 10.,  9.,  1., 11., 12.,
#        15.])

# %%
df = df.drop(df[(df['baths']==0) & (df['bedrooms'] > 3)].index)
df
# Out:
#            price           location  baths      area  bedrooms
# 0      220000000         Model Town    0.0   6 Kanal       0.0
# 1       40000000        Multan Road    5.0   1 Kanal       5.0
# 2        9500000               Eden    0.0   9 Marla       3.0
# 3      125000000            Gulberg    7.0   1 Kanal       8.0
# 4       21000000  Allama Iqbal Town    5.0  11 Marla       6.0
# ...          ...                ...    ...       ...       ...
# 58616      55000  Allama Iqbal Town    0.0   3 Marla       3.0
# 58619     600000    New Muslim Town    0.0   2 Kanal       0.0
# 58627     185000        DHA Defence    6.0   1 Kanal       5.0
# 58628     150000        DHA Defence    5.0  10 Marla       4.0
# 58630      70000        Bahria Town    4.0   5 Marla       3.0
#
# [45074 rows x 5 columns]

# %%
df.drop(df[(df['bedrooms']==0) | (df['baths']==0)].index, inplace=True)

# %%
df[df["baths"] > df["bedrooms"]].head(25)
# Out:
#         price                           location  baths       area  bedrooms
# 5    52000000                            Gulberg    6.0    1 Kanal       5.0
# 6    16500000  Military Accounts Housing Society    7.0    8 Marla       6.0
# 11   87500000                         Upper Mall    5.0  1.2 Kanal       4.0
# 17   50000000                        Agrics Town    7.0   18 Marla       6.0
# 19   27500000                             Askari    5.0   12 Marla       4.0
# 21   50000000                         Upper Mall    6.0    1 Kanal       5.0
# 22   45000000                             Askari    6.0    1 Kanal       5.0
# 24   21200000                             Askari    4.0   10 Marla       3.0
# 25   23000000                             Askari    5.0   10 Marla       4.0
# 26   21500000                             Askari    5.0   10 Marla       4.0
# 27   21500000                             Askari    5.0   10 Marla       4.0
# 28   40000000                             Askari    6.0    1 Kanal       5.0
# 29   26000000                             Askari    5.0   10 Marla       4.0
# 31   23000000                             Askari    5.0   10 Marla       4.0
# 32   23000000                             Askari    6.0   10 Marla       5.0
# 36   50000000                            Gulberg    6.0    1 Kanal       5.0
# 43   40000000                        EME Society    7.0    1 Kanal       6.0
# 44  180000000                            Gulberg    7.0  4.7 Kanal       5.0
# 45   17000000                      Mateen Avenue    6.0  9.7 Marla       5.0
# 48   25000000                 IEP Engineers Town    5.0   18 Marla       4.0
# 49   17600000                        Bahria Town    6.0   10 Marla       5.0
# 50   17500000                        Bahria Town    6.0   10 Marla       5.0
# 51   35000000                             Askari    5.0   17 Marla       4.0
# 52   22000000                             Askari    5.0   10 Marla       4.0
# 53   23500000                             Askari    6.0   10 Marla       5.0

# %%
df.drop(df[df['baths'] > df['bedrooms']].index, inplace=True)

# %%
df.head()
# Out:
#         price           location  baths       area  bedrooms
# 1    40000000        Multan Road    5.0    1 Kanal       5.0
# 3   125000000            Gulberg    7.0    1 Kanal       8.0
# 4    21000000  Allama Iqbal Town    5.0   11 Marla       6.0
# 10   13500000               Eden    4.0  7.5 Marla       4.0
# 12    8500000   Park View Villas    4.0    5 Marla       4.0

# %% [markdown]
# ## OUTLIERS DETECTION AND REMOVALS

# %%
print(df.columns)
# Out:
# Index(['price', 'location', 'baths', 'area', 'bedrooms'], dtype='object')

# %%
import re

def convert_to_sqft(area):
    area = str(area)
    if 'Marla' in area:
        area = float(re.sub(r'\D+', '', area)) * 272.251
    elif 'Kanal' in area:
        area = float(re.sub(r'\D+', '', area)) * 5445
    return area

df['area'] = df['area'].apply(convert_to_sqft)

# %%
df.head()
# Out:
#         price           location  baths       area  bedrooms
# 1    40000000        Multan Road    5.0   5445.000       5.0
# 3   125000000            Gulberg    7.0   5445.000       8.0
# 4    21000000  Allama Iqbal Town    5.0   2994.761       6.0
# 10   13500000               Eden    4.0  20418.825       4.0
# 12    8500000   Park View Villas    4.0   1361.255       4.0

# %%
df['price_per_sqft'] = df['price'] / df['area']
df.head()
# Out:
#         price           location  baths       area  bedrooms  price_per_sqft
# 1    40000000        Multan Road    5.0   5445.000       5.0     7346.189164
# 3   125000000            Gulberg    7.0   5445.000       8.0    22956.841139
# 4    21000000  Allama Iqbal Town    5.0   2994.761       6.0     7012.245718
# 10   13500000               Eden    4.0  20418.825       4.0      661.154596
# 12    8500000   Park View Villas    4.0   1361.255       4.0     6244.237854

# %%
len(df['location'].unique())
# Out:
# 558

# %%
df['location'] = df['location'].apply(lambda x: x.strip())
location_stats = df.groupby('location')['location'].agg('count').sort_values(ascending=False)
location_stats.head(40)
# Out:
# location
# DHA Defence                          1677
# Bahria Town                          1449
# Johar Town                            997
# Allama Iqbal Town                     701
# Gulberg                               593
# Al Rehman Garden                      518
# Bahria Orchard                        490
# Wapda Town                            467
# Model Town                            443
# Askari                                385
# Lalazaar Garden                       366
# Pak Arab Housing Society              361
# Sabzazar Scheme                       344
# Cantt                                 336
# Samanabad                             324
# Park View Villas                      318
# Gulshan-e-Ravi                        289
# Lahore Medical Housing Society        279
# State Life Housing Society            278
# DHA 11 Rahbar                         277
# Military Accounts Housing Society     261
# Eden                                  259
# EME Society                           243
# Township                              206
# Harbanspura                           200
# Lake City                             191
# Valencia Housing Society              174
# Tajpura                               173
# Al-Kabir Town                         167
# Khayaban-e-Amin                       154
# Canal Garden                          146
# Nishtar Colony                        142
# Garden Town                           140
# Tariq Gardens                         138
# Bismillah Housing Scheme              135
# Shershah Colony - Raiwind Road        135
# Canal View                            133
# Jubilee Town                          130
# GT Road                               114
# Canal Bank Housing Scheme             112
# Name: location, dtype: int64

# %%
# DIMENSION Reduction as removing those location having properties less then 10
locations_less_than_10 = location_stats[location_stats <= 10]
df['location'] = df['location'].apply(lambda x:'others' if x in locations_less_than_10 else x)

# %%
df[df['area'] / df['bedrooms'] < 300]
# Out:
#          price                           location  baths      area  bedrooms  \
# 23     3200000                  Chungi Amar Sadhu    2.0   816.753       3.0
# 71     6000000                  Allama Iqbal Town    2.0   544.502       3.0
# 72     5500000                  Allama Iqbal Town    2.0   544.502       3.0
# 119    4500000                     Al Faisal Town    3.0   544.502       3.0
# 210    8200000  Military Accounts Housing Society    4.0  1089.004       4.0
# ...        ...                                ...    ...       ...       ...
# 58191    28000                  Allama Iqbal Town    3.0   816.753       3.0
# 58192    28000                  Allama Iqbal Town    3.0   816.753       3.0
# 58193    28000                  Allama Iqbal Town    3.0   816.753       3.0
# 58338  8000000                    Lalazaar Garden    3.0   816.753       3.0
# 58348  3300000                         Mughalpura    2.0   272.251       2.0
#
#        price_per_sqft
# 23        3917.953163
# 71       11019.243272
# 72       10100.972999
# 119       8264.432454
# 210       7529.816236
# ...               ...
# 58191       34.282090
# 58192       34.282090
# 58193       34.282090
# 58338     9794.882908
# 58348    12121.167599
#
# [4402 rows x 6 columns]

# %% [markdown]
# In the above cell we assume that on minimum a bedroom must be more than 300 sq.ft so those that were not following that rule in our data we will be removing them as they will be considered as outliers...

# %%
df.drop(df[df['area'] / df['bedrooms'] < 300].index, inplace = True)

# %%
df['price_per_sqft'].describe()
# Out:
# count     16595.000000
# mean       6013.459059
# std        4187.637706
# min           0.003673
# 25%        3060.900909
# 50%        6703.397612
# 75%        8631.740563
# max      106519.351628
# Name: price_per_sqft, dtype: float64

# %% [markdown]
# Notice how much it is having standard deviation we will reduce it...

# %%
# removing price_per_sqft outliers 
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key,subdf in df.groupby('location'):
        m = np.mean(subdf['price_per_sqft'])
        std = np.std(subdf['price_per_sqft'])
        reduced_df = subdf[(subdf['price_per_sqft'] > (m-std)) & (subdf['price_per_sqft'] <= (m+std))]
        df_out = pd.concat([df_out,reduced_df], ignore_index=True)
    return df_out

# %%
df = remove_pps_outliers(df)
df.shape
# Out:
# (12042, 6)

# %%
def plot_scatter_chart(df, location):
    bedroom_2 = df[(df['location'] == location) & (df['bedrooms'] == 2)]
    bedroom_3 = df[(df['location'] == location) & (df['bedrooms'] == 3)]
    matplotlib.rcParams["figure.figsize"] = (15,10)
    plt.scatter(bedroom_2['area'], bedroom_2['price']/100000, color='blue', label="2 Bedroom", s=50)
    plt.scatter(bedroom_3['area'], bedroom_3['price']/100000, marker='+', color="green", label="3 Bedroom", s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price")
    plt.title(location)
    plt.legend()

# %%
plot_scatter_chart(df, "Johar Town")

# %% [markdown]
# Notice in the above graph that there are some properties having 3 bedrooms still in less price than 2 bedrooms properties in a specfied location. Now they can also be considered as outliers and we should also remove them so that they cannot affect our model performance

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby("location"):
        bhk_stats = {}
        for bedroom, bedroom_df in location_df.groupby("bedrooms"):
            bhk_stats[bedroom] = {
                'mean' : np.mean(bedroom_df["price_per_sqft"]),
                'std' : np.std(bedroom_df["price_per_sqft"]),
                'count': bedroom_df.shape[0]
            }
        for bedroom, bedroom_df in location_df.groupby("bedrooms"):
            stats = bhk_stats.get(bedroom - 1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bedroom_df[bedroom_df['price_per_sqft'] < (stats['mean'])].index.values)
    return df.drop(exclude_indices, axis="index")

# %%
df = remove_bhk_outliers(df)
df.shape
# Out:
# (8628, 6)

# %%
df.groupby('location')['location'].agg('count').sort_values(ascending=False).head(40)
# Out:
# location
# Bahria Town                             825
# DHA Defence                             522
# Bahria Orchard                          455
# others                                  355
# Johar Town                              313
# Park View Villas                        285
# Allama Iqbal Town                       272
# Gulberg                                 231
# DHA 11 Rahbar                           227
# Askari                                  212
# Model Town                              210
# Pak Arab Housing Society                193
# Al Rehman Garden                        184
# Military Accounts Housing Society       184
# Wapda Town                              182
# Khayaban-e-Amin                         121
# State Life Housing Society              120
# Lahore Medical Housing Society          112
# Cantt                                   109
# Lake City                               108
# Valencia Housing Society                 97
# Eden                                     93
# EME Society                              79
# Tariq Gardens                            76
# Gulshan-e-Ravi                           69
# Canal Garden                             69
# Paragon City                             68
# College Road                             67
# Defence Road                             65
# Township                                 64
# Izmir Town                               61
# Architects Engineers Housing Society     59
# Canal View                               54
# PIA Housing Scheme                       52
# Sabzazar Scheme                          51
# Garden Town                              51
# Harbanspura                              46
# Ferozepur Road                           45
# GT Road                                  45
# Bahria Nasheman                          43
# Name: location, dtype: int64

# %%
plot_scatter_chart(df,"Faisal Town")

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.hist(df['price_per_sqft'], rwidth=0.8)
plt.xlabel("Price Per Square Ft")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Then we plot the graph and 8000 price per square ft is the most common price

# %%
df = df.drop(df[df['baths'] > (df['bedrooms'] + 2)].index)
df.shape
# Out:
# (8628, 6)

# %%
df1 = df.drop("price_per_sqft", axis=1)

# %% [markdown]
# As we add the column price_per_sqft for our dimensionality reduction we will now remove this column as this is not a feature for predicting property pricing...

# %%
dummies = pd.get_dummies(df1['location'])
dummies.head(3)
# Out:
#    Aashiana Road  Abdalians Cooperative Housing Society  \
# 3              1                                      0
# 6              1                                      0
# 8              1                                      0
#
#    Airline Housing Society  Airport Road  Al Faisal Town  Al Hafeez Gardens  \
# 3                        0             0               0                  0
# 6                        0             0               0                  0
# 8                        0             0               0                  0
#
#    Al Jalil Garden  Al Rehman Garden  Al-Hafiz Town  Al-Hamad Colony (AIT)  \
# 3                0                 0              0                      0
# 6                0                 0              0                      0
# 8                0                 0              0                      0
#
#    ...  Valencia Housing Society  Wahdat Road  Walled City  Walton Road  \
# 3  ...                         0            0            0            0
# 6  ...                         0            0            0            0
# 8  ...                         0            0            0            0
#
#    Wapda Town  Wassanpura  West Wood Housing Society  Zaheer Villas  \
# 3           0           0                          0              0
# 6           0           0                          0              0
# 8           0           0                          0              0
#
#    Zaitoon - New Lahore City  others
# 3                          0       0
# 6                          0       0
# 8                          0       0
#
# [3 rows x 203 columns]

# %% [markdown]
# First we make dummies of our locations

# %%
df1 = pd.concat([df1, dummies.drop('others', axis=1)], axis="columns")
df1 = df1.drop("location", axis=1)
df1.head()
df1.shape
# Out:
# (8628, 206)

# %% [markdown]
# Then we concat them with our data...

# %% [markdown]
# ## MODEL BUILDING AND EVALUATION

# %%
X = df1.drop('price', axis=1) # Features
X.head()
# Out:
#     baths      area  bedrooms  Aashiana Road  \
# 3     2.0  2722.510       4.0              1
# 6     3.0  1361.255       3.0              1
# 8     1.0   544.502       1.0              1
# 9     1.0   544.502       1.0              1
# 11    4.0  1361.255       4.0              1
#
#     Abdalians Cooperative Housing Society  Airline Housing Society  \
# 3                                       0                        0
# 6                                       0                        0
# 8                                       0                        0
# 9                                       0                        0
# 11                                      0                        0
#
#     Airport Road  Al Faisal Town  Al Hafeez Gardens  Al Jalil Garden  ...  \
# 3              0               0                  0                0  ...
# 6              0               0                  0                0  ...
# 8              0               0                  0                0  ...
# 9              0               0                  0                0  ...
# 11             0               0                  0                0  ...
#
#     UET Housing Society  Valencia Housing Society  Wahdat Road  Walled City  \
# 3                     0                         0            0            0
# 6                     0                         0            0            0
# 8                     0                         0            0            0
# 9                     0                         0            0            0
# 11                    0                         0            0            0
#
#     Walton Road  Wapda Town  Wassanpura  West Wood Housing Society  \
# 3             0           0           0                          0
# 6             0           0           0                          0
# 8             0           0           0                          0
# 9             0           0           0                          0
# 11            0           0           0                          0
#
#     Zaheer Villas  Zaitoon - New Lahore City
# 3               0                          0
# 6               0                          0
# 8               0                          0
# 9               0                          0
# 11              0                          0
#
# [5 rows x 205 columns]

# %%
y = df1['price'] # Predictor or predicted_variable
y.head()
# Out:
# 3     14000000
# 6      8000000
# 8      2500000
# 9      2500000
# 11     6500000
# Name: price, dtype: int64

# %% [markdown]
# As the price of property is continuous so we will be using regression models

# %%
from sklearn.model_selection import train_test_split # for dividing data into training and test sets
from sklearn.linear_model import LinearRegression # for predicting price


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
lr = LinearRegression()
lr.fit(X_train, y_train)
print("Accuracy:",lr.score(X_test, y_test)*100,"%")
# Out:
# Accuracy: 62.83383019482186 %

# %%
import matplotlib.pyplot as plt
import sklearn
from sklearn.tree import DecisionTreeRegressor

# create the decision tree regressor object
dtr = DecisionTreeRegressor(criterion='friedman_mse', splitter='random', random_state=0)

# fit the regressor to the training data
dtr.fit(X, y)

# Plot the decision tree
plt.figure(figsize=(15,80))
tree.plot_tree(dtr, filled=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8120\3528399268.py in <module>
#      11 # Plot the decision tree
#      12 plt.figure(figsize=(15,80))
# ---> 13 tree.plot_tree(dtr, filled=True);
#
# NameError: name 'tree' is not defined

# %%
from sklearn.metrics import mean_absolute_error


predictions = dtr.predict(X)
mae = mean_absolute_error(y, predictions)

# define the tolerance (5% of the range of the target variable)
tolerance = 0.05 * (np.max(y) - np.min(y))

# calculate the number of predictions that are within the tolerance of the true values
num_correct = np.sum(np.abs(y - predictions) <= tolerance)

# calculate the accuracy as a percentage of the number of correct predictions
accuracy = 100 * num_correct / len(y)

print("Accuracy: {:.2f}%".format(accuracy))
# Out:
# Accuracy: 100.00%

# %%
X.columns
# Out:
# Index(['baths', 'area', 'bedrooms', 'Aashiana Road',
#        'Abdalians Cooperative Housing Society', 'Airline Housing Society',
#        'Airport Road', 'Al Faisal Town', 'Al Hafeez Gardens',
#        'Al Jalil Garden',
#        ...
#        'UET Housing Society', 'Valencia Housing Society', 'Wahdat Road',
#        'Walled City', 'Walton Road', 'Wapda Town', 'Wassanpura',
#        'West Wood Housing Society', 'Zaheer Villas',
#        'Zaitoon - New Lahore City'],
#       dtype='object', length=205)

# %%
def predict_price(location, sqft, bedrooms, baths):
    loc_index = np.where(X.columns==location)[0][0]
    
    x = np.zeros(len(X.columns))
    x[0] = baths
    x[1] = sqft
    x[2] = bedrooms
    if loc_index >= 0:
        x[loc_index] = 1
    return dtr.predict([x])[0] / 100000

# %%
# 7 Marla
print(str(int(predict_price('Bahria Town', 1905.757, 5, 4))) + " Lakhs")
# Out:
# 165 Lakhs

# %%
print(str(int(predict_price('UET Housing Society', 1905.757, 5, 4))) + " Lakhs")
# Out:
# 140 Lakhs

# %%
result = df[(df['location'] == 'Bahria Town') & (df['baths'] == 4.0) & (df['bedrooms'] == 5.0)]
print(result)
# Out:
#          price     location  baths      area  bedrooms  price_per_sqft
# 1916  23000000  Bahria Town    4.0  2722.510       5.0     8448.086508
# 2098  16500000  Bahria Town    4.0  1905.757       5.0     8657.976856
# 2490  24000000  Bahria Town    4.0  2722.510       5.0     8815.394617

# %%
# 10 Marla
print(str(int(predict_price('Bahria Town', 2722.510, 5, 4))) + " Lakhs")
# Out:
# 235 Lakhs
